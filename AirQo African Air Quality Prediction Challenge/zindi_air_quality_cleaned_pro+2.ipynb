# %% [markdown]
# <h1><b> Import Modules

# %%
import time

# %%
start=time.time()

# %%
import pandas as pd                                    # for data
import numpy as np                                     # for math
from lightgbm import LGBMRegressor                     # Validation model
from sklearn.metrics import mean_squared_error         # Regressortion metric
from sklearn.model_selection import GroupKFold,KFold   # for validation
from sklearn.preprocessing import LabelEncoder         # for encoding
import sklearn.manifold._t_sne as tsne                 # for t_sne
import seaborn as sns                                  # for plotting
import matplotlib.pyplot as plt                         # for plotting

# %% [markdown]
# <h1><b>Define Functions

# %%
def post_process(test_data,y,feature_to_mean='date_month') -> int:
    """runs the post processing

    Keyword arguments:
    test_data -- the testing data
    y -- the target
    feature_to_mean -- feature to apply the post processing by
    Return: predictions after processing
    """
    test_data['target'] = y
    test_data['target_month'] = test_data[feature_to_mean].map(test_data[[feature_to_mean,'target']].groupby(feature_to_mean)['target'].mean())
    test_data.drop(columns='target',inplace=True)
    return test_data['target_month']

# %% [markdown]
# <h1><b> Read Data

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")

# %%
train.columns
# Out:
# Index(['id', 'site_id', 'site_latitude', 'site_longitude', 'city', 'country',
#        'date', 'hour', 'sulphurdioxide_so2_column_number_density',
#        'sulphurdioxide_so2_column_number_density_amf',
#        'sulphurdioxide_so2_slant_column_number_density',
#        'sulphurdioxide_cloud_fraction', 'sulphurdioxide_sensor_azimuth_angle',
#        'sulphurdioxide_sensor_zenith_angle',
#        'sulphurdioxide_solar_azimuth_angle',
#        'sulphurdioxide_solar_zenith_angle',
#        'sulphurdioxide_so2_column_number_density_15km', 'month',
#        'carbonmonoxide_co_column_number_density',
#        'carbonmonoxide_h2o_column_number_density',
#        'carbonmonoxide_cloud_height', 'carbonmonoxide_sensor_altitude',
#        'carbonmonoxide_sensor_azimuth_angle',
#        'carbonmonoxide_sensor_zenith_angle',
#        'carbonmonoxide_solar_azimuth_angle',
#        'carbonmonoxide_solar_zenith_angle',
#        'nitrogendioxide_no2_column_number_density',
#        'nitrogendioxide_tropospheric_no2_column_number_density',
#        'nitrogendioxide_stratospheric_no2_column_number_density',
#        'nitrogendioxide_no2_slant_column_number_density',
#        'nitrogendioxide_tropopause_pressure',
#        'nitrogendioxide_absorbing_aerosol_index',
#        'nitrogendioxide_cloud_fraction', 'nitrogendioxide_sensor_altitude',
#        'nitrogendioxide_sensor_azimuth_angle',
#        'nitrogendioxide_sensor_zenith_angle',
#        'nitrogendioxide_solar_azimuth_angle',
#        'nitrogendioxide_solar_zenith_angle',
#        'formaldehyde_tropospheric_hcho_column_number_density',
#        'formaldehyde_tropospheric_hcho_column_number_density_amf',
#        'formaldehyde_hcho_slant_column_number_density',
#        'formaldehyde_cloud_fraction', 'formaldehyde_solar_zenith_angle',
#        'formaldehyde_solar_azimuth_angle', 'formaldehyde_sensor_zenith_angle',
#        'formaldehyde_sensor_azimuth_angle',
#        'uvaerosolindex_absorbing_aerosol_index',
#        'uvaerosolindex_sensor_altitude', 'uvaerosolindex_sensor_azimuth_angle',
#        'uvaerosolindex_sensor_zenith_angle',
#        'uvaerosolindex_solar_azimuth_angle',
#        'uvaerosolindex_solar_zenith_angle', 'ozone_o3_column_number_density',
#        'ozone_o3_column_number_density_amf',
#        'ozone_o3_slant_column_number_density',
#        'ozone_o3_effective_temperature', 'ozone_cloud_fraction',
#        'ozone_sensor_azimuth_angle', 'ozone_sensor_zenith_angle',
#        'ozone_solar_azimuth_angle', 'ozone_solar_zenith_angle',
#        'uvaerosollayerheight_aerosol_height',
#        'uvaerosollayerheight_aerosol_pressure',
#        'uvaerosollayerheight_aerosol_optical_depth',
#        'uvaerosollayerheight_sensor_zenith_angle',
#        'uvaerosollayerheight_sensor_azimuth_angle',
#        'uvaerosollayerheight_solar_azimuth_angle',
#        'uvaerosollayerheight_solar_zenith_angle', 'cloud_cloud_fraction',
#        'cloud_cloud_top_pressure', 'cloud_cloud_top_height',
#        'cloud_cloud_base_pressure', 'cloud_cloud_base_height',
#        'cloud_cloud_optical_depth', 'cloud_surface_albedo',
#        'cloud_sensor_azimuth_angle', 'cloud_sensor_zenith_angle',
#        'cloud_solar_azimuth_angle', 'cloud_solar_zenith_angle', 'pm2_5'],
#       dtype='object')

# %%
pd.options.display.max_columns = 200

# %% [markdown]
# <h1><b> Data Preprocessing

# %%
train_feats = train.notna().sum()[train.notna().sum() > .15*len(train)].index
test_feats = test.notna().sum()[test.notna().sum() > .15*len(test)].index
train = train[train_feats]

# %%
test = test[train_feats[:-1]]

# %%
train.head()
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_vjcx08sz91  6531a46a89b3300013914a36        6.53257         3.39936
# 1  id_bkg215syli  6531a46a89b3300013914a36        6.53257         3.39936
# 2  id_oui2pot3qd  6531a46a89b3300013914a36        6.53257         3.39936
# 3  id_9aandqzy4n  6531a46a89b3300013914a36        6.53257         3.39936
# 4  id_ali5x2m4iw  6531a46a89b3300013914a36        6.53257         3.39936
#
#     city  country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Lagos  Nigeria  2023-10-25    13                                       NaN
# 1  Lagos  Nigeria  2023-11-02    12                                       NaN
# 2  Lagos  Nigeria  2023-11-03    13                                       NaN
# 3  Lagos  Nigeria  2023-11-08    14                                       NaN
# 4  Lagos  Nigeria  2023-11-09    13                                  0.000267
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                      0.774656
#
#    sulphurdioxide_so2_slant_column_number_density  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        0.000207
#
#    sulphurdioxide_cloud_fraction  sulphurdioxide_sensor_azimuth_angle  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                       0.223403                           -97.811241
#
#    sulphurdioxide_sensor_zenith_angle  sulphurdioxide_solar_azimuth_angle  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                           49.513344                         -126.064468
#
#    sulphurdioxide_solar_zenith_angle  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                          40.167336
#
#    sulphurdioxide_so2_column_number_density_15km  month  \
# 0                                            NaN   10.0
# 1                                            NaN   11.0
# 2                                            NaN   11.0
# 3                                            NaN   11.0
# 4                                       0.000083   11.0
#
#    carbonmonoxide_co_column_number_density  \
# 0                                      NaN
# 1                                 0.045475
# 2                                      NaN
# 3                                      NaN
# 4                                 0.049045
#
#    carbonmonoxide_h2o_column_number_density  carbonmonoxide_cloud_height  \
# 0                                       NaN                          NaN
# 1                               3771.027210                  3399.756845
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                               3514.042054                  1678.370478
#
#    carbonmonoxide_sensor_altitude  carbonmonoxide_sensor_azimuth_angle  \
# 0                             NaN                                  NaN
# 1                   828569.623806                            69.245351
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                   828902.790450                           -96.099639
#
#    carbonmonoxide_sensor_zenith_angle  carbonmonoxide_solar_azimuth_angle  \
# 0                                 NaN                                 NaN
# 1                           59.159695                         -143.370575
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                           49.432796                         -126.070747
#
#    carbonmonoxide_solar_zenith_angle  \
# 0                                NaN
# 1                          26.566997
# 2                                NaN
# 3                                NaN
# 4                          40.144183
#
#    nitrogendioxide_no2_column_number_density  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                   0.000097
#
#    nitrogendioxide_tropospheric_no2_column_number_density  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000063
#
#    nitrogendioxide_stratospheric_no2_column_number_density  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000035
#
#    nitrogendioxide_no2_slant_column_number_density  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                         0.000175
#
#    nitrogendioxide_tropopause_pressure  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                          9582.712645
#
#    nitrogendioxide_absorbing_aerosol_index  nitrogendioxide_cloud_fraction  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                 0.069667                        0.142913
#
#    nitrogendioxide_sensor_altitude  nitrogendioxide_sensor_azimuth_angle  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                         828919.0                            -97.811241
#
#    nitrogendioxide_sensor_zenith_angle  nitrogendioxide_solar_azimuth_angle  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                            49.513344                          -126.064468
#
#    nitrogendioxide_solar_zenith_angle  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           40.167336
#
#    formaldehyde_tropospheric_hcho_column_number_density  \
# 0                                                NaN
# 1                                           0.000214
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000100
#
#    formaldehyde_tropospheric_hcho_column_number_density_amf  \
# 0                                                NaN
# 1                                           1.462390
# 2                                                NaN
# 3                                                NaN
# 4                                           1.298433
#
#    formaldehyde_hcho_slant_column_number_density  formaldehyde_cloud_fraction  \
# 0                                            NaN                          NaN
# 1                                       0.000240                     0.359150
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                       0.000068                     0.223403
#
#    formaldehyde_solar_zenith_angle  formaldehyde_solar_azimuth_angle  \
# 0                              NaN                               NaN
# 1                        26.525513                       -143.480164
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                        40.167336                       -126.064468
#
#    formaldehyde_sensor_zenith_angle  formaldehyde_sensor_azimuth_angle  \
# 0                               NaN                                NaN
# 1                         59.220097                          70.875954
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                         49.513344                         -97.811241
#
#    uvaerosolindex_absorbing_aerosol_index  uvaerosolindex_sensor_altitude  \
# 0                                0.052301                     828817.9375
# 1                               -0.315206                     828578.6250
# 2                                1.097816                     828878.6875
# 3                                0.591543                     828920.6875
# 4                                0.069669                     828919.0000
#
#    uvaerosolindex_sensor_azimuth_angle  uvaerosolindex_sensor_zenith_angle  \
# 0                          -100.805145                           21.720518
# 1                            70.875954                           59.220097
# 2                           -96.411942                           61.045010
# 3                           -95.863083                           65.508858
# 4                           -97.811241                           49.513344
#
#    uvaerosolindex_solar_azimuth_angle  uvaerosolindex_solar_zenith_angle  \
# 0                         -123.523796                          33.745914
# 1                         -143.480164                          26.525513
# 2                         -121.307121                          41.898113
# 3                         -122.218231                          43.923038
# 4                         -126.064468                          40.167336
#
#    ozone_o3_column_number_density  ozone_o3_column_number_density_amf  \
# 0                        0.122055                            2.301404
# 1                        0.116975                            3.049902
# 2                        0.117559                            3.248703
# 3                        0.118412                            3.505708
# 4                        0.117899                            2.796072
#
#    ozone_o3_slant_column_number_density  ozone_o3_effective_temperature  \
# 0                              0.285803                      230.693756
# 1                              0.362203                      228.260193
# 2                              0.384168                      224.102463
# 3                              0.416643                      226.529633
# 4                              0.334256                      226.368851
#
#    ozone_cloud_fraction  ozone_sensor_azimuth_angle  \
# 0              0.906039                 -100.805145
# 1              0.364713                   70.875954
# 2              0.754163                  -96.411942
# 3              1.000000                  -95.863083
# 4              0.226150                  -97.811241
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  21.720518                -123.523796
# 1                  59.220097                -143.480164
# 2                  61.045010                -121.307121
# 3                  65.508858                -122.218231
# 4                  49.513344                -126.064468
#
#    ozone_solar_zenith_angle  cloud_cloud_fraction  cloud_cloud_top_pressure  \
# 0                 33.745914                   NaN                       NaN
# 1                 26.525513                   NaN                       NaN
# 2                 41.898113              0.756392               45185.49959
# 3                 43.923038                   NaN                       NaN
# 4                 40.167336              0.226141               86197.53125
#
#    cloud_cloud_top_height  cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0                     NaN                        NaN                      NaN
# 1                     NaN                        NaN                      NaN
# 2             6791.682888               51171.802486              5791.682829
# 3                     NaN                        NaN                      NaN
# 4             1451.050659               96215.906250               451.050598
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                  11.816715              0.192757
# 3                        NaN                   NaN
# 4                  10.521009              0.153114
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                  -96.411890                  61.045123
# 3                         NaN                        NaN
# 4                  -97.811241                  49.513439
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle      pm2_5
# 0                        NaN                       NaN  12.015000
# 1                        NaN                       NaN  42.267200
# 2                -121.307414                 41.898269  39.450741
# 3                        NaN                       NaN  10.537600
# 4                -126.064453                 40.167355  19.431731

# %%
test.head()
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_ihxgrbq8bw  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 1  id_dg6s4fhiwe  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 2  id_f7hwwtmuzp  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 3  id_ioese5awdg  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 4  id_hdw320zpls  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
#
#     city country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Accra   Ghana  2023-09-06    13                                 -0.000072
# 1  Accra   Ghana  2023-09-07    13                                       NaN
# 2  Accra   Ghana  2023-09-08    13                                 -0.000051
# 3  Accra   Ghana  2023-09-09    12                                       NaN
# 4  Accra   Ghana  2023-09-20    12                                 -0.000634
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                                      0.762543
# 1                                           NaN
# 2                                      1.004265
# 3                                           NaN
# 4                                      0.632173
#
#    sulphurdioxide_so2_slant_column_number_density  \
# 0                                       -0.000055
# 1                                             NaN
# 2                                       -0.000051
# 3                                             NaN
# 4                                       -0.000401
#
#    sulphurdioxide_cloud_fraction  sulphurdioxide_sensor_azimuth_angle  \
# 0                       0.079645                          -100.330299
# 1                            NaN                                  NaN
# 2                       0.163160                            73.117264
# 3                            NaN                                  NaN
# 4                       0.000000                            70.066956
#
#    sulphurdioxide_sensor_zenith_angle  sulphurdioxide_solar_azimuth_angle  \
# 0                           26.926420                          -86.879776
# 1                                 NaN                                 NaN
# 2                           43.112466                          -89.089083
# 3                                 NaN                                 NaN
# 4                           66.014107                         -111.396515
#
#    sulphurdioxide_solar_zenith_angle  \
# 0                          25.512329
# 1                                NaN
# 2                          16.417355
# 3                                NaN
# 4                          12.226210
#
#    sulphurdioxide_so2_column_number_density_15km  month  \
# 0                                      -0.000028    9.0
# 1                                            NaN    9.0
# 2                                      -0.000023    9.0
# 3                                            NaN    9.0
# 4                                      -0.000147    9.0
#
#    carbonmonoxide_co_column_number_density  \
# 0                                 0.043537
# 1                                 0.036341
# 2                                 0.037453
# 3                                      NaN
# 4                                      NaN
#
#    carbonmonoxide_h2o_column_number_density  carbonmonoxide_cloud_height  \
# 0                               2825.323242                     1.000000
# 1                               2604.788330                  1584.809692
# 2                               3046.314001                    90.699029
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#    carbonmonoxide_sensor_altitude  carbonmonoxide_sensor_azimuth_angle  \
# 0                     829406.9375                           -97.787621
# 1                     829328.6250                            70.753090
# 2                     829194.5625                            71.272375
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
#
#    carbonmonoxide_sensor_zenith_angle  carbonmonoxide_solar_azimuth_angle  \
# 0                           26.897718                          -86.884308
# 1                           11.428769                          -87.764297
# 2                           43.172868                          -88.964294
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    carbonmonoxide_solar_zenith_angle  \
# 0                          25.509418
# 1                          20.935318
# 2                          16.440554
# 3                                NaN
# 4                                NaN
#
#    nitrogendioxide_no2_column_number_density  \
# 0                                   0.000055
# 1                                        NaN
# 2                                   0.000062
# 3                                        NaN
# 4                                   0.000046
#
#    nitrogendioxide_tropospheric_no2_column_number_density  \
# 0                                           0.000016
# 1                                                NaN
# 2                                           0.000027
# 3                                                NaN
# 4                                           0.000013
#
#    nitrogendioxide_stratospheric_no2_column_number_density  \
# 0                                           0.000040
# 1                                                NaN
# 2                                           0.000036
# 3                                                NaN
# 4                                           0.000033
#
#    nitrogendioxide_no2_slant_column_number_density  \
# 0                                         0.000109
# 1                                              NaN
# 2                                         0.000134
# 3                                              NaN
# 4                                         0.000132
#
#    nitrogendioxide_tropopause_pressure  \
# 0                          9582.745678
# 1                                  NaN
# 2                          9582.743944
# 3                                  NaN
# 4                          8614.471169
#
#    nitrogendioxide_absorbing_aerosol_index  nitrogendioxide_cloud_fraction  \
# 0                                -0.258421                        0.019749
# 1                                      NaN                             NaN
# 2                                -0.115200                        0.163328
# 3                                      NaN                             NaN
# 4                                -0.211310                        0.072076
#
#    nitrogendioxide_sensor_altitude  nitrogendioxide_sensor_azimuth_angle  \
# 0                    829420.312500                           -100.330299
# 1                              NaN                                   NaN
# 2                    829204.480816                             73.117264
# 3                              NaN                                   NaN
# 4                    828876.562500                             70.066956
#
#    nitrogendioxide_sensor_zenith_angle  nitrogendioxide_solar_azimuth_angle  \
# 0                            26.926420                           -86.879776
# 1                                  NaN                                  NaN
# 2                            43.112466                           -89.089083
# 3                                  NaN                                  NaN
# 4                            66.014107                          -111.396515
#
#    nitrogendioxide_solar_zenith_angle  \
# 0                           25.512329
# 1                                 NaN
# 2                           16.417355
# 3                                 NaN
# 4                           12.226210
#
#    formaldehyde_tropospheric_hcho_column_number_density  \
# 0                                           0.000243
# 1                                                NaN
# 2                                           0.000145
# 3                                                NaN
# 4                                          -0.000193
#
#    formaldehyde_tropospheric_hcho_column_number_density_amf  \
# 0                                           1.112240
# 1                                                NaN
# 2                                           1.345840
# 3                                                NaN
# 4                                           1.285203
#
#    formaldehyde_hcho_slant_column_number_density  formaldehyde_cloud_fraction  \
# 0                                       0.000213                     0.079645
# 1                                            NaN                          NaN
# 2                                       0.000127                     0.163160
# 3                                            NaN                          NaN
# 4                                      -0.000316                     0.000000
#
#    formaldehyde_solar_zenith_angle  formaldehyde_solar_azimuth_angle  \
# 0                        25.512329                        -86.879776
# 1                              NaN                               NaN
# 2                        16.417355                        -89.089083
# 3                              NaN                               NaN
# 4                        12.226210                       -111.396515
#
#    formaldehyde_sensor_zenith_angle  formaldehyde_sensor_azimuth_angle  \
# 0                         26.926420                        -100.330299
# 1                               NaN                                NaN
# 2                         43.112466                          73.117264
# 3                               NaN                                NaN
# 4                         66.014107                          70.066956
#
#    uvaerosolindex_absorbing_aerosol_index  uvaerosolindex_sensor_altitude  \
# 0                               -0.258422                   829420.312500
# 1                               -0.408162                   829340.750000
# 2                               -0.115169                   829204.480816
# 3                               -1.116044                   829067.312500
# 4                               -0.211314                   828876.562500
#
#    uvaerosolindex_sensor_azimuth_angle  uvaerosolindex_sensor_zenith_angle  \
# 0                          -100.330299                           26.926420
# 1                            76.400116                           11.171532
# 2                            73.117264                           43.112466
# 3                            70.680077                           61.874397
# 4                            70.066956                           66.014107
#
#    uvaerosolindex_solar_azimuth_angle  uvaerosolindex_solar_zenith_angle  \
# 0                          -86.879776                          25.512329
# 1                          -87.726566                          20.951560
# 2                          -89.089083                          16.417355
# 3                          -90.875526                          11.865146
# 4                         -111.396515                          12.226210
#
#    ozone_o3_column_number_density  ozone_o3_column_number_density_amf  \
# 0                        0.126056                            2.243713
# 1                        0.126282                            2.136400
# 2                        0.126162                            2.428528
# 3                        0.121339                            3.074277
# 4                        0.127799                            3.335475
#
#    ozone_o3_slant_column_number_density  ozone_o3_effective_temperature  \
# 0                              0.286278                      230.244171
# 1                              0.273757                      230.184377
# 2                              0.311882                      237.772241
# 3                              0.378890                      225.704056
# 4                              0.432085                      237.175858
#
#    ozone_cloud_fraction  ozone_sensor_azimuth_angle  \
# 0              0.079324                 -100.330299
# 1              0.613266                   76.400116
# 2              0.164370                   73.117264
# 3              0.845910                   70.680077
# 4              0.000000                   70.066956
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  26.926420                 -86.879776
# 1                  11.171532                 -87.726566
# 2                  43.112466                 -89.089083
# 3                  61.874397                 -90.875526
# 4                  66.014107                -111.396515
#
#    ozone_solar_zenith_angle  cloud_cloud_fraction  cloud_cloud_top_pressure  \
# 0                 25.512329              0.043065              74217.403083
# 1                 20.951560                   NaN                       NaN
# 2                 16.417355                   NaN                       NaN
# 3                 11.865146              0.845911              46052.449219
# 4                 12.226210                   NaN                       NaN
#
#    cloud_cloud_top_height  cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0             2710.544562               83569.504246              1710.544483
# 1                     NaN                        NaN                      NaN
# 2                     NaN                        NaN                      NaN
# 3             6585.034668               52160.980469              5585.034668
# 4                     NaN                        NaN                      NaN
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                   3.063105              0.263193
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                  29.145922              0.314945
# 4                        NaN                   NaN
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                 -100.317077                  27.059646
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                   70.680077                  61.874222
# 4                         NaN                        NaN
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle
# 0                 -86.885670                 25.530511
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                 -90.875603                 11.865201
# 4                        NaN                       NaN

# %% [markdown]
# <h2><b>Add Time-related Features

# %%
for df in (train,test):
    df['date'] = pd.to_datetime(df['date'])
    df['date_month'] = df['date'].dt.day_of_year
    df['DayOfWeek'] =  df['date'].dt.dayofweek
    df['Day'] =  df['date'].dt.day
    df['Year'] =  df['date'].dt.year
    df.drop(columns=['site_id','date'],inplace=True)
# Out:
# <ipython-input-1122-aef047e96ec2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# <ipython-input-1122-aef047e96ec2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_month'] = df['date'].dt.day_of_year
# <ipython-input-1122-aef047e96ec2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] =  df['date'].dt.dayofweek
# <ipython-input-1122-aef047e96ec2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] =  df['date'].dt.day
# <ipython-input-1122-aef047e96ec2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] =  df['date'].dt.year
# <ipython-input-1122-aef047e96ec2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['site_id','date'],inplace=True)
# <ipython-input-1122-aef047e96ec2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# <h3><b> Grouping

# %%
groups = train['city']

# %% [markdown]
# - groups is a variable that stores the city column from the train DataFrame.
# - This is used later for grouping the data during cross-validation.
#
# - In this context, groups represent the different cities in the train dataset.
# - By using groups, the cross-validation process can be performed within each city,
# - ensuring that the model is trained and evaluated on data from the same city.
# - the model might not perform as well because it would not have been exposed to the same distribution of data.
# - By using groups, the model is trained and evaluated on data from the same city,
# - which helps to ensure that the model is able to generalize well to unseen data.

# %% [markdown]
# <h2><b> Encoding

# %% [markdown]
# <h4><b>Label Encoding

# %%
le = LabelEncoder()
for column in ['city','country','id']:
    letrans = le.fit_transform(pd.concat([train,test])[column])
    train[column] = letrans[:len(train)]
    test[column] = letrans[len(train):]

# %% [markdown]
# <h1><b>Modeling

# %%
model =  LGBMRegressor(n_estimators=200,random_state=42,max_depth=10)
n_splits = 4
cv = GroupKFold(n_splits=n_splits)

# %% [markdown]
# <h1><b>Validation

# %%
train_set = pd.read_csv('Train.csv')
test_set = pd.read_csv('Test.csv')

def validate(trainset,testset,t,origin):
    model.fit(trainset.drop(columns=t),trainset[t])
    pred = model.predict(np.array(testset.drop(columns=t)))
    print('std: ', testset[t].std())
    # pred = post_process(origin,pred,'date_month')

    origin['pm_5'] = pred
    origin['date'] = pd.to_datetime(origin['date'])
    origin['date_day'] = origin['date'].dt.month
    pred = origin['date_day'].map(origin[['date_day','pm_5']].groupby('date_day')['pm_5'].mean())
    stds.append(testset[t].std())
    score = mean_squared_error(pred,testset[t],squared=False)
    print('score:', score)
    return score
stds = []
rmse = []
for v_train,v_test in cv.split(train.drop(columns='pm2_5'),train['pm2_5'],groups=groups):
    train_v, test_v= train.iloc[v_train],train.iloc[v_test]
    origin = train_set.iloc[v_test]
    rmse.append(validate(train_v,test_v,'pm2_5',origin))
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16640
# [LightGBM] [Info] Number of data points in the train set: 2475, number of used features: 74
# [LightGBM] [Info] Start training from score 28.876230
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# std:  14.34682858151784
# score: 14.213006742282468
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005823 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16748
# [LightGBM] [Info] Number of data points in the train set: 6571, number of used features: 74
# [LightGBM] [Info] Start training from score 25.954156
# <ipython-input-1126-4b78dc60a841>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# <ipython-input-1126-4b78dc60a841>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date'] = pd.to_datetime(origin['date'])
# <ipython-input-1126-4b78dc60a841>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['date'].dt.month
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# std:  24.982218437683237
# score: 25.11749634778974
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# <ipython-input-1126-4b78dc60a841>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# <ipython-input-1126-4b78dc60a841>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date'] = pd.to_datetime(origin['date'])
# <ipython-input-1126-4b78dc60a841>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['date'].dt.month
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16717
# [LightGBM] [Info] Number of data points in the train set: 7219, number of used features: 74
# [LightGBM] [Info] Start training from score 22.093092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# std:  52.84388334184576
# score: 52.690842609120686
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# <ipython-input-1126-4b78dc60a841>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# <ipython-input-1126-4b78dc60a841>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date'] = pd.to_datetime(origin['date'])
# <ipython-input-1126-4b78dc60a841>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['date'].dt.month
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16760
# [LightGBM] [Info] Number of data points in the train set: 7948, number of used features: 74
# [LightGBM] [Info] Start training from score 24.545522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# std:  22.35338406057941
# score: 18.313434647724534
# <ipython-input-1126-4b78dc60a841>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['pm_5'] = pred
# <ipython-input-1126-4b78dc60a841>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date'] = pd.to_datetime(origin['date'])
# <ipython-input-1126-4b78dc60a841>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   origin['date_day'] = origin['date'].dt.month

# %%
np.array(rmse).mean()
# Out:
# 27.583695086729357

# %% [markdown]
# <h1><b>Inference

# %%
model.fit(train.drop(columns='pm2_5'),train['pm2_5'])
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16775
# [LightGBM] [Info] Number of data points in the train set: 8071, number of used features: 74
# [LightGBM] [Info] Start training from score 24.639296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(max_depth=10, n_estimators=200, random_state=42)

# %%
y = model.predict(test)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %% [markdown]
# <h1><b> Make The Submission File

# %%
smaple = pd.read_csv('SampleSubmission.csv')
smaple['pm2_5'] = post_process(test,y)
smaple.to_csv('submission2.csv',index=False)

# %%
sample_plus=pd.read_csv('/content/submission 16.9.csv')

# %%
from sklearn.metrics import mean_absolute_error

# %%
MAE_score = mean_absolute_error(smaple['pm2_5'],sample_plus['pm2_5'])

# %%
print(MAE_score)
# Out:
# 1.5635650784920747

# %%
end=time.time()

# %%
excution=end-start

# %%
print(excution)
# Out:
# 14.417007207870483
